# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

import sys
sys.path.append('..')
from util import *
from data import read_AAPL, read_engineer_salaries

from matplotlib import dates as mpl_dates

# %%
# Data
import os
data_directory = os.getcwd() + '/../../bin/'
# print(data_directory)
stock_data = read_AAPL(data_directory)
stock_data_select = stock_data[['Date', 'Close']][stock_data.index % 200 == 0]

print(stock_data_select.head())
# Out:
#            Date     Close
# 0    1980-12-12  0.099058
# 200  1981-09-29  0.052113
# 400  1982-07-15  0.043930
# 600  1983-04-28  0.172274
# 800  1984-02-10  0.083984

# %%
plt.title('AAPL Stock Price')
plt.plot(stock_data_select['Date'], stock_data_select['Close'], linestyle = '--')
plt.fill_between(stock_data_select['Date'], stock_data_select['Close'], alpha = 0.25)
plt.show()

# %%
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
stock_data.sort_values('Date', inplace=True)

print(stock_data_select.head())
# Out:
#            Date     Close
# 0    1980-12-12  0.099058
# 200  1981-09-29  0.052113
# 400  1982-07-15  0.043930
# 600  1983-04-28  0.172274
# 800  1984-02-10  0.083984

# %%
plt.plot_date(stock_data_select['Date'], stock_data_select['Close'], linestyle = '--')

# %%
plt.plot_date(stock_data_select['Date'], stock_data_select['Close'], linestyle = '--')

## Should have a better formatter
date_format = mpl_dates.DateFormatter('%b, %Y')

plt.gca().xaxis.set_major_formatter(date_format)
plt.gcf().autofmt_xdate()
